# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisCarlosRinconG/CursoPython_UniCafam/blob/main/Taller1_1007404854.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![images.png](data:image/png;base64,...)
#
#
# **TALLER 1**
#
# CURSO DE PYTHON
#
# DIRECCION DE EDUCACIÓN CONTINUA
#
# FUNDACION UNIVERSITARIA CAFAM
#
# DOCENTE: NICOLAS MOJICA GOMEZ
#
# ESTUDIANTE: **LUIS CARLOS RINCÓN GORDO**
#
#
# ---

# %% [markdown]
# ***Ejercicio 1: Creación y Modificación de Listas***
#
# 1. Crea una lista llamada números que contenga los números del 1 al 5.
# 2. Añade el número 6 al final de la lista numeros.
# 3. Cambia el segundo elemento de la lista numeros a 10.
# 4. Elimina el cuarto elemento de la lista numeros

# %%
# 1. Crea una lista llamada números que contenga los números del 1 al 5.
numeros=[1,2,3,4,5]
print('----------------------------------Primer punto----------------------------------')
print(numeros)
# 2. Añade el número 6 al final de la lista numeros.
print('----------------------------------Segundo punto----------------------------------')
numeros.append(6)
print(numeros)
# 3. Cambia el segundo elemento de la lista numeros a 10.
print('----------------------------------Tercer punto----------------------------------')
numeros[1]=10
print(numeros)
# 4. Elimina el cuarto elemento de la lista numeros
print('----------------------------------Cuarto punto----------------------------------')
numeros.remove(6)
print(numeros)
# Out:
# ----------------------------------Primer punto----------------------------------
# [1, 2, 3, 4, 5]
# ----------------------------------Segundo punto----------------------------------
# [1, 2, 3, 4, 5, 6]
# ----------------------------------Tercer punto----------------------------------
# [1, 10, 3, 4, 5, 6]
# ----------------------------------Cuarto punto----------------------------------
# [1, 10, 3, 4, 5]

# %% [markdown]
# ---
# ***Ejercicio 2: Creación de Tuplas***
#
# 1. Crea una tupla llamada colores que contenga los colores 'rojo', 'verde', y 'azul'.
# 2. Accede al primer elemento de la tupla colores

# %%
# 1) Crea una tupla llamada colores que contenga los colores 'rojo', 'verde', y 'azul'.
colores=[ 'rojo', 'verde', 'azul']
tuple(colores)
print('----------------------------------Primer punto----------------------------------')
print(colores)

# 2) Accede al primer elemento de la tupla colores
print('----------------------------------Segundo punto----------------------------------')
print(colores[0])
# Out:
# ----------------------------------Primer punto----------------------------------
# ['rojo', 'verde', 'azul']
# ----------------------------------Segundo punto----------------------------------
# rojo

# %% [markdown]
# ***Ejercicio 3: Creación y Modificación de Diccionarios***
# 1. Crea un diccionario llamado persona con las claves nombre, edad y ciudad.
# 2. Cambia el valor de edad a 31.
# 3. Añade una nueva clave profesion con el valor Ingeniero.
# 4. Elimina la clave ciudad del diccionario persona.

# %%
# 1) Crea un diccionario llamado persona con las claves nombre, edad y ciudad.
persona={'nombre':'','edad':0,'ciudad':''}
print('----------------------------------Primer punto----------------------------------')
print(persona)

# 2) Cambia el valor de edad a 31
persona['edad']=31
print('----------------------------------Segundo punto----------------------------------')
print(persona)

# 3) Añade una nueva clave profesion con el valor Ingeniero.
persona['profesion']='ingeniero'
print('----------------------------------Tercer punto----------------------------------')
print(persona)

# 4) Elimina la clave ciudad del diccionario persona
del persona['ciudad']
print('----------------------------------Cuarto punto----------------------------------')
print(persona)
# Out:
# ----------------------------------Primer punto----------------------------------
# {'nombre': '', 'edad': 0, 'ciudad': ''}
# ----------------------------------Segundo punto----------------------------------
# {'nombre': '', 'edad': 31, 'ciudad': ''}
# ----------------------------------Tercer punto----------------------------------
# {'nombre': '', 'edad': 31, 'ciudad': '', 'profesion': 'ingeniero'}
# ----------------------------------Cuarto punto----------------------------------
# {'nombre': '', 'edad': 31, 'profesion': 'ingeniero'}

# %% [markdown]
# ***Ejercicio 4: Operadores Matemáticos***
# 1. Declara dos variables a y b con los valores 10 y 3, respectivamente.
# 2. Calcula la suma de a y b y asígnala a una variable suma.
# 3. Calcula la resta de a y b y asígnala a una variable resta.
# 4. Calcula la multiplicación de a y b y asígnala a una variable multiplicacion.
# 5. Calcula la división de a entre b y asígnala a una variable division.
# 6. Calcula el módulo de a y b y asígnalo a una variable modulo.
# 7. Calcula la potencia de a elevado a b y asígnala a una variable potencia.
# 8. Calcula la división entera de a entre b y asígnala a una variable division_entera.

# %%
#1) Declara dos variables a y b con los valores 10 y 3, respectivamente.
a=10
b=3
print('----------------------------------Primer punto----------------------------------')
print('los números son: ',a ,' y ', b)
#2) Calcula la suma de a y b y asígnala a una variable suma.
suma=a+b
print('----------------------------------Segundo punto----------------------------------')
print(suma)
#3) Calcula la resta de a y b y asígnala a una variable resta.
resta=a-b
print('----------------------------------Tercer punto----------------------------------')
print(resta)
#4) Calcula la multiplicación de a y b y asígnala a una variable multiplicacion.
multiplicacion=a*b
print('----------------------------------cuarto punto----------------------------------')
print(multiplicacion)

#5) Calcula la división de a entre b y asígnala a una variable division.
division=a/b
print('----------------------------------quinto punto----------------------------------')
print(division)

#6) Calcula el módulo de a y b y asígnalo a una variable modulo.
modulo=a%b
print('----------------------------------sesto punto----------------------------------')
print(modulo)

#7) Calcula la potencia de a elevado a b y asígnala a una variable potencia.
potencia=a**b
print('----------------------------------septimo punto----------------------------------')
print(potencia)

#8) Calcula la división entera de a entre b y asígnala a una variable division_entera.
division_entera=a//b
print('----------------------------------octavo punto----------------------------------')
print(division_entera)
# Out:
# ----------------------------------Primer punto----------------------------------
# los números son:  10  y  3
# ----------------------------------Segundo punto----------------------------------
# 13
# ----------------------------------Tercer punto----------------------------------
# 7
# ----------------------------------cuarto punto----------------------------------
# 30
# ----------------------------------quinto punto----------------------------------
# 3.3333333333333335
# ----------------------------------sesto punto----------------------------------
# 1
# ----------------------------------septimo punto----------------------------------
# 1000
# ----------------------------------octavo punto----------------------------------
# 3

# %% [markdown]
# ***Ejercicio 5: Valores de Cadena***
# 1. Declara una cadena llamada saludo con el valor "Hola, mundo!".
# 2. Accede y muestra el primer carácter de la cadena saludo.
# 3. Accede y muestra los últimos 5 caracteres de la cadena saludo.
# 4. Concatenar la cadena saludo con otra cadena ", ¿cómo estás?" y asígnala a una
# nueva variable saludo_completo.
# 5. Convierte la cadena saludo_completo a mayúsculas y asígnala a una variable
# saludo_mayusculas.
# 6. Reemplaza la palabra "mundo" en saludo_completo por "Python" y asígnala a una
# variable saludo_reemplazo.

# %%
#1. Declara una cadena llamada saludo con el valor "Hola, mundo!".
saludo='Hola, mundo!'
print('----------------------------------Primer punto----------------------------------')
print(saludo)
#2. Accede y muestra el primer carácter de la cadena saludo.
print('----------------------------------Segundo punto----------------------------------')
print(saludo[0])
#3. Accede y muestra los últimos 5 caracteres de la cadena saludo.
print('----------------------------------Tercer punto----------------------------------')
print(saludo[7:12])
#4. Concatenar la cadena saludo con otra cadena ", ¿cómo estás?" y asígnala a una nueva variable saludo_completo.
print('----------------------------------Cuarto punto----------------------------------')
saludo_completo=', ¿cómo estás?'
print(saludo+saludo_completo)
#5. Convierte la cadena saludo_completo a mayúsculas y asígnala a una variable saludo_mayusculas.
print('----------------------------------Quinto punto----------------------------------')
saludo_mayusculas=saludo+saludo_completo
print(saludo+saludo_completo.upper())
#6. Reemplaza la palabra "mundo" en saludo_completo por "Python" y asígnala a una variable saludo_reemplazo.
saludo_reemplazo=saludo_mayusculas
print('----------------------------------sesto punto----------------------------------')
print(saludo_reemplazo.replace('mundo','Python'))
# Out:
# ----------------------------------Primer punto----------------------------------
# Hola, mundo!
# ----------------------------------Segundo punto----------------------------------
# H
# ----------------------------------Tercer punto----------------------------------
# undo!
# ----------------------------------Cuarto punto----------------------------------
# Hola, mundo!, ¿cómo estás?
# ----------------------------------Quinto punto----------------------------------
# Hola, mundo!, ¿CÓMO ESTÁS?
# ----------------------------------sesto punto----------------------------------
# Hola, Python!, ¿cómo estás?
